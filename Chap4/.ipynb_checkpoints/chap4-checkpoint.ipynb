# %%
v = [0.5, 0.75, 1.0, 1.5, 2.0, 1.2]

print(sum(v[-2:]))
# Out:
# 3.2

# %%
import array

# %%
a = array.array('f', v)

# %%
arr = [3.7430, 3.9427, 3.8904, 3.8668, 3.7156, 3.7666, 3.6140, 3.6488, 3.6495, 3.5031, 3.4551, 3.3554, 3.2945]

sum(arr)
# Out:
# 47.44550000000001

# %%
f
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-a9fcd54b25e7> in <module>
# ----> 1 f
#
# NameError: name 'f' is not defined

# %%
a.append('hi')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-6cfd9a83c9c5> in <module>
# ----> 1 a.append('hi')
#
# TypeError: must be real number, not str

# %%
a = array.array('s', v)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-955d3a62f78c> in <module>
# ----> 1 a = array.array('s', v)
#
# ValueError: bad typecode (must be b, B, u, h, H, i, I, l, L, q, Q, f or d)

# %%
f = open('array.apy', 'wb')

# %%
a.tofile(f)
f.close()

# %%
with open('array.apy', 'wb') as f:
# Out:
#   File "<ipython-input-10-d0e6f29c05ec>", line 1
#     with open('array.apy', 'wb') as f:
#                                       ^
# SyntaxError: unexpected EOF while parsing

# %%
with open('array.apy', 'wb') as f:
     a.tofile(f)

# %%
# !ls -n arr*
# Out:
# -rw-r--r--  1 501  20  20 Jul 18 10:01 array.apy

# %%
b = array.array('f')

# %%
b
# Out:
# array('f')

# %%
with open('array.apy', 'rb') as f:
    b.fromfile(f, 5)

# %%
b
# Out:
# array('f', [0.5, 0.75, 1.0, 1.5, 2.0])

# %%
f
# Out:
# <_io.BufferedReader name='array.apy'>

# %%
b
# Out:
# array('f', [0.5, 0.75, 1.0, 1.5, 2.0])

# %%
f
# Out:
# <_io.BufferedReader name='array.apy'>

# %%
f = open('array.apy', 'wb')
a.tofile(f)
f.close()

# %%
f
# Out:
# <_io.BufferedWriter name='array.apy'>

# %%
b = array.array('f')

# %%
with open('array.apy', 'rb') as f:
    b.fromfile(f, 5)

# %%
b
# Out:
# array('f', [0.5, 0.75, 1.0, 1.5, 2.0])

# %%
f
# Out:
# <_io.BufferedReader name='array.apy'>

# %%
f = open('array.apy', 'wb')

# %%
f
# Out:
# <_io.BufferedWriter name='array.apy'>

# %%
with open('array.apy', 'rb') as f:
   print(f)
# Out:
# <_io.BufferedReader name='array.apy'>

# %%
import json

# %%
import json
import datetime

input_file = open ('array.json')
json_array = json.load(input_file)
store_list = []
atr_list = [3.7430, 3.9427, 3.8904, 3.8668, 3.7156, 3.7666, 3.6140, 3.6488, 3.6495, 3.5031, 3.4551, 3.3554, 3.2945]

previous_close = 0

for item in json_array:
    store_details = {"low":None, "close":None, "atr14":None, "date":None}
    store_details['low'] = item[3]
    store_details['close'] = item[4]
    if len(store_list) < len(atr_list):
        store_details['atr14'] = atr_list[len(store_list)]
    else:
        tr = float(item[2]) - float(item[3])
        atr = (sum(atr_list[-13:]) + tr)/14
        atr_list.append(atr)
        store_details['atr14'] = atr_list[-1]
    store_details['date'] = datetime.datetime.fromtimestamp(item[0] / 1e3)
    store_list.append(store_details)
    previous_close = float(item[3])
    
print(atr_list)
# Out:
# [3.743, 3.9427, 3.8904, 3.8668, 3.7156, 3.7666, 3.614, 3.6488, 3.6495, 3.5031, 3.4551, 3.3554, 3.2945, 3.5403928571428582, 3.6094923469387754, 3.4421203717201165, 3.4365289697001247, 3.428652467535848, 3.331013358074123, 3.327757169365132, 4.533739824319785, 4.869092668914055, 4.080492145265058, 3.8503058699268484, 4.331392003493053, 3.983962860885413, 4.183210208091513, 4.036268590302131,