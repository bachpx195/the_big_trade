# %%
MERCHAINDISE = 'ADAUSDT'
DAYS = 1000

# format = YYYY-MM-DD
START_DATE = '2021-10-2'
END_DATE = '2021-12-7'

DATE_FORMAT = "%Y-%m-%d"

# %%
from myenv.models.candlestick import Candlestick
from myenv.helpers.constants import HIGH_INDEX, LOW_INDEX, OPEN_INDEX, CLOSE_INDEX
from myenv.models.merchandise_rate import MerchandiseRate
from myenv.helpers.utils import percentage_change, candlestick_type, type_continuous, diff_days, unique_list, draw_candlestick
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline


merchandise_rate = MerchandiseRate()
merchandise_rate_id = merchandise_rate.find_by_slug(MERCHAINDISE)
# candlestick = Candlestick(merchandise_rate_id, 'hour', 24*DAYS, "DESC")
candlestick = Candlestick(merchandise_rate_id, 'hour', 24*DAYS, "DESC")

data_prices = candlestick.to_df()

draw_candlestick(data_prices).show()

# %%
from myenv.mod  els.candlestick import Candlestick
from myenv.helpers.constants import HIGH_INDEX, LOW_INDEX, OPEN_INDEX, CLOSE_INDEX
from myenv.models.merchandise_rate import MerchandiseRate
from myenv.helpers.utils import percentage_change, candlestick_type, type_continuous, diff_days, unique_list, draw_candlestick
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline


merchandise_rate = MerchandiseRate()
merchandise_rate_id = merchandise_rate.find_by_slug(MERCHAINDISE)
# candlestick = Candlestick(merchandise_rate_id, 'hour', 24*DAYS, "DESC")
candlestick = Candlestick(merchandise_rate_id, 'month', 24*DAYS, "DESC")

data_prices = candlestick.to_df()

draw_candlestick(data_prices).show()
