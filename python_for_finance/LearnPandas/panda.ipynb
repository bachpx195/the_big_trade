# %% [markdown]
# # Creating & reading & writing

# %%
import pandas as pd 
# pd.read_csv()

# %% [markdown]
# ## DataFrame
#
# A DataFrame is a table. It contains an array of individual entries, each of which has a certain value. Each entry corresponds to a row (or record) and a column.

# %%
df = pd.DataFrame({'Bob': ['I liked it.', 'It was awful.', 'dkm'], 'Sue': ['Pretty good.', 'Bland.', 'mkd']})
df[2:]
# Out:
#    Bob  Sue
# 2  dkm  mkd

# %% [markdown]
# ## Series
# A Series, by contrast, is a sequence of data values. If a DataFrame is a table, a Series is a list. And in fact you can create one with nothing more than a list:

# %%
import pandas as pd 
pd.Series([30, 35, 40], index=['2015 Sales', '2016 Sales', '2017 Sales'], name='Product A')
# Out:
# 2015 Sales    30
# 2016 Sales    35
# 2017 Sales    40
# Name: Product A, dtype: int64

# %% [markdown]
# `Series` is a single column of a DataFrame

# %% [markdown]
# ## Reading data files

# %%
import pandas as pd
import datetime

# use pd.read_csv() function to read the data into a DataFrame
bitcoin_prices = pd.read_csv("../data/bitcoin_price.csv")



# shape attribute to check large the resulting DataFrame is
# bitcoin_prices.shape

# head() to examine
# print(bitcoin_prices.head())

# ('Jun 1 2005  1:33PM', '%b %d %Y %I:%M%p')
# dt = time.strptime(bitcoin_prices['Date'][0], '%b %d, %Y')

# convert Date column to datetime
bitcoin_prices['Date']= pd.to_datetime(bitcoin_prices['Date']) 

# set date column is index
bitcoin_prices = bitcoin_prices.set_index('Date')

# tail() to see end of file
# print(bitcoin_prices.tail(6))

# Get data by 2017
seven_teen_df = bitcoin_prices.loc['2013-05-03':'2013-04-28']

print(bitcoin_prices['Open'])

# (1) We could smooth the data with a rolling average
bitcoin_prices['Open'].rolling(100).mean().plot()

# type(seven_teen_df)
# Out:
# Date
# 2017-07-31    2763.24
# 2017-07-30    2724.39
# 2017-07-29    2807.02
# 2017-07-28    2679.73
# 2017-07-27    2538.71
#                ...
# 2013-05-02     116.38
# 2013-05-01     139.00
# 2013-04-30     144.00
# 2013-04-29     134.44
# 2013-04-28     135.30
# Name: Open, Length: 1556, dtype: float64

# %% [markdown]
# ### (1) Rolling window in econometrics
#
# “Rolling window” simply means that, you apply the method or model you use repeatedly to the sub-data sets or sub-series in your full data set or series.

# %% [markdown]
# ![image.png](attachment:image.png)
